# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dfVPC = pd.read_csv('/content/drive/MyDrive/NoCountry|S14-27/TablasTransformadas/SalidasInternacionalesUSA.csv')

# %%
dfVPC = dfVPC.sample(250)

# %%
dfVPC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 355228 to 595510
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Año            250 non-null    int64
#  1   Mes            250 non-null    int64
#  2   IDAeropuertoO  250 non-null    int64
#  3   AeropuertoO    250 non-null    object
#  4   IDAeropuertoD  250 non-null    int64
#  5   AeropuertoD    250 non-null    object
#  6   IDAerolinea    250 non-null    int64
#  7   Aerolinea      249 non-null    object
#  8   TablaOrigen    250 non-null    object
#  9   VPasajerosC    250 non-null    float64
#  10  VPasajerosP    250 non-null    float64
#  11  VCargaC        158 non-null    float64
#  12  VCargaP        158 non-null    float64
#  13  AsientosC      180 non-null    float64
#  14  AsientosP      180 non-null    float64
#  15  PasajerosC     177 non-null    float64
#  16  PasajerosP     177 non-null    float64
# ...

# %% [markdown]
# ### mysql db
# ---

# %%
#conectors
# !pip install mysqlclient
#!pip install mysql-connector-python
#!pip install pymysql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 6.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mysqlclient: filename=mysqlclient-2.2.4-cp310-cp310-linux_x86_64.whl size=124740 sha256=52cba19b6c7e24855f360b352eb9ffa4899cb7bbb6f780573d602c2f69b3bd4d
#   Stored in directory: /root/.cache/pip/wheels/ac/96/ac/2a4d8cb58a4d95de1dffc3f8b0ea42e0e5b63ab97640edbda3
# Successfully built mysqlclient
# ...

# %%
#import
import pandas as pd
import MySQLdb
#import pymsql
#import mysql.connector
from sqlalchemy import create_engine

# %% [markdown]
# #### sqlalchemy
# ---

# %%
#create engine
engine = create_engine('mysql://root:aAkKgEemjdDubcojVPOjQOluxgdvwDKp@roundhouse.proxy.rlwy.net:36214/railway')
#engine = create_engine('mysql+pymysql://root:aAkKgEemjdDubcojVPOjQOluxgdvwDKp@roundhouse.proxy.rlwy.net:36214/railway')
#engine = create_engine('mysql+mysqlconnector://root:aAkKgEemjdDubcojVPOjQOluxgdvwDKp@roundhouse.proxy.rlwy.net:36214/railway')

# %%
#write
dfVPC.to_sql('tableOne', con=engine, if_exists='replace', index=False)
# Out:
# 250

# %%
#read
df = pd.read_sql(sql='select * from tableOne', con=engine)

# %%
df
# Out:
#       Año  Mes  IDAeropuertoO AeropuertoO  IDAeropuertoD AeropuertoD  \
# 0    2013   12          14843         SJU          11654         FDF
# 1    2021    6          12339         IND          16128         YMX
# 2    2019    8          15070         SWF          14918         SNN
# 3    2014    5          12892         LAX          14309         PVG
# 4    2019    3          10185         AEX          14677         SAL
# ..    ...  ...            ...         ...            ...         ...
# 245  2005    4          11278         DCA          16217         YUL
# 246  1991   11          13303         MIA          10911         CCS
# 247  1996    8          10721         BOS          10292         AMS
# 248  2005   10          10540         BED          16271         YYZ
# 249  1995    7          13204         MCO          12010         GUA
#
#      IDAerolinea Aerolinea                                        TablaOrigen  \
# ...

# %% [markdown]
# #### sqlalchemy opcion 2
# ---

# %%
from sqlalchemy.sql import text

# %%
con = engine.connect()

# %%
#read
res = con.execute(text('select * from tableOne'))

# %%
res.keys()
# Out:
# RMKeyView(['Año', 'Mes', 'IDAeropuertoO', 'AeropuertoO', 'IDAeropuertoD', 'AeropuertoD', 'IDAerolinea', 'Aerolinea', 'TablaOrigen', 'VPasajerosC', 'VPasajerosP', 'VCargaC', 'VCargaP', 'AsientosC', 'AsientosP', 'PasajerosC', 'PasajerosP'])

# %%
df = pd.DataFrame(res.fetchall())

# %%
df
# Out:
#       Año  Mes  IDAeropuertoO AeropuertoO  IDAeropuertoD AeropuertoD  \
# 0    2013   12          14843         SJU          11654         FDF
# 1    2021    6          12339         IND          16128         YMX
# 2    2019    8          15070         SWF          14918         SNN
# 3    2014    5          12892         LAX          14309         PVG
# 4    2019    3          10185         AEX          14677         SAL
# ..    ...  ...            ...         ...            ...         ...
# 245  2005    4          11278         DCA          16217         YUL
# 246  1991   11          13303         MIA          10911         CCS
# 247  1996    8          10721         BOS          10292         AMS
# 248  2005   10          10540         BED          16271         YYZ
# 249  1995    7          13204         MCO          12010         GUA
#
#      IDAerolinea Aerolinea                                        TablaOrigen  \
# ...

# %%
#update
con.execute(text("update tableOne set AeropuertoD = 'holaMundo' where AeropuertoO = 'MIA'"))

# %%
res = con.execute(text('select * from tableOne'))
df = pd.DataFrame(res.fetchall())
df
# Out:
#       Año  Mes  IDAeropuertoO AeropuertoO  IDAeropuertoD AeropuertoD  \
# 0    2013   12          14843         SJU          11654         FDF
# 1    2021    6          12339         IND          16128         YMX
# 2    2019    8          15070         SWF          14918         SNN
# 3    2014    5          12892         LAX          14309         PVG
# 4    2019    3          10185         AEX          14677         SAL
# ..    ...  ...            ...         ...            ...         ...
# 245  2005    4          11278         DCA          16217         YUL
# 246  1991   11          13303         MIA          10911   holaMundo
# 247  1996    8          10721         BOS          10292         AMS
# 248  2005   10          10540         BED          16271         YYZ
# 249  1995    7          13204         MCO          12010         GUA
#
#      IDAerolinea Aerolinea                                        TablaOrigen  \
# ...

# %%
#drop table
#con.execute(text("drop table tableOne"))

# %% [markdown]
# #### close connection
# ---

# %%
con.close()

# %% [markdown]
# #### without sqlalchemy
# ---

# %%
import

# %%
try:
    connection = mysql.connector.connect(host='roundhouse.proxy.rlwy.net',
                                         database='railway',
                                         port='36214',
                                         user='root',
                                         password='aAkKgEemjdDubcojVPOjQOluxgdvwDKp')

    if connection.is_connected():
      print('OK!')

    sql = "select * from tableOne"
    cursor = connection.cursor()
    cursor.execute(sql)

    # get all records
    res = cursor.fetchall()
    print("Total number of rows in table: ", cursor.rowcount)

    for row in res:
        print(row)

except mysql.connector.Error as e:
    print("Error reading data from MySQL", e)
finally:
    if connection.is_connected():
        connection.close()
        print("MySQL connection is closed")
# Out:
# OK!
# Total number of rows in table:  250
# (2013, 12, 14843, 'SJU', 11654, 'FDF', 20280, 'SEB', "['VueloPasajeros', 'VueloCarga', 'Asientos', 'Pasajeros']", 35.0, 0.0, 10.0, 0.0, 1190.0, 0.0, 863.0, 0.0)
# (2021, 6, 12339, 'IND', 16128, 'YMX', 20107, 'FX', "['VueloPasajeros', 'VueloCarga']", 40.0, 0.0, 941.0, 0.0, None, None, None, None)
# (2019, 8, 15070, 'SWF', 14918, 'SNN', 19977, 'UA', "['VueloPasajeros', 'Asientos', 'Pasajeros']", 1.0, 0.0, None, None, 169.0, 0.0, 167.0, 0.0)
# (2014, 5, 12892, 'LAX', 14309, 'PVG', 20133, 'CZ', "['VueloPasajeros', 'VueloCarga']", 50.0, 0.0, 3734.0, 0.0, None, None, None, None)
# (2019, 3, 10185, 'AEX', 14677, 'SAL', 20310, 'WL', "['VueloPasajeros', 'Asientos']", 0.0, 1.0, None, None, 0.0, 155.0, None, None)
# (2015, 12, 12016, 'GUM', 12690, 'KIJ', 19550, 'KE', "['VueloPasajeros', 'Asientos', 'Pasajeros']", 0.0, 1.0, None, None, 0.0, 159.0, 0.0, 132.0)
# ...
